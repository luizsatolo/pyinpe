# %%
# !pip install pyinpe -q
from pyinpe.WFS import connectDeter, getAlerts

# Connect to INPE's DETER Cerrado WFS
connectDeter()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().system('pip install pyinpe -q')
# ----> 2 from pyinpe.WFS import get_contents, get_collectionSchema
#       4 # Get collections at INPE's DETER Cerrado WFS
#       5 get_contents(database = 'deter_cerrado')
#
# ModuleNotFoundError: No module named 'pyinpe.WFS'

# %%
# Get a geodataframe with alerts for the city of Posse, Goias in 2020
getAlerts(spatial_filter='Posse - GO', temporal_filter=['2020-01-01', '2020-12-31'])

# %%
# Get a geodataframe with alerts for a bounding box [x_min, y_min, x_max, y_max]
getAlerts(spatial_filter = [-53.5,-21,-53,-20.5])

# %%
# Get a geodataframe with alerts that overlaps a WKT geometry
getAlerts(spatial_filter = 'POLYGON ((-46.3 -14.3, -46.2 -14.2, -46.2 -14.3, -46.3 -14.3))', temporal_filter=['2020-01-01', '2024-12-31'])
